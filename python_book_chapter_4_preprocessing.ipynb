# %%
import pandas as pd

# %%
my_series = pd.Series([19,20,18,19,14,17,19], name='marks')
my_series
# Out:
# 0    19
# 1    20
# 2    18
# 3    19
# 4    14
# 5    17
# 6    19
# Name: marks, dtype: int64

# %%
my_series.shape
# Out:
# (7,)

# %%
my_series.index
# Out:
# RangeIndex(start=0, stop=7, step=1)

# %%
df = pd.read_csv('/content/sample_data/california_housing_train.csv', sep=',')

# %%
df = pd.read_excel('/content/DiabetesDiagnosis.xls')

# %%
df.head(4)
# Out:
#    Pregnancies  PG Concentration  Diastolic BP  ...  DP Function  Age  Diagnosis
# 0            6               148            72  ...        0.627   50          0
# 1            1                85            66  ...        0.351   31          1
# 2            8               183            64  ...        0.672   32          0
# 3            1                89            66  ...        0.167   21          1
#
# [4 rows x 9 columns]

# %%
df.tail(3)
# Out:
#      Pregnancies  PG Concentration  Diastolic BP  ...  DP Function  Age  Diagnosis
# 765            5               121            72  ...        0.245   30          1
# 766            1               126            60  ...        0.349   47          0
# 767            1                93            70  ...        0.315   23          1
#
# [3 rows x 9 columns]

# %%
df = df.set_index('BMI')
df.head(3)
# Out:
#       Pregnancies  PG Concentration  Diastolic BP  ...  DP Function  Age  Diagnosis
# BMI                                                ...
# 33.6            6               148            72  ...        0.627   50          0
# 26.6            1                85            66  ...        0.351   31          1
# 23.3            8               183            64  ...        0.672   32          0
#
# [3 rows x 8 columns]

# %%
df=df.reset_index()
df.head(3)
# Out:
#     BMI  Pregnancies  PG Concentration  ...  DP Function  Age  Diagnosis
# 0  33.6            6               148  ...        0.627   50          0
# 1  26.6            1                85  ...        0.351   31          1
# 2  23.3            8               183  ...        0.672   32          0
#
# [3 rows x 9 columns]

# %%
df = pd.read_excel('/content/DiabetesDiagnosis.xls', header=None)
df.head()
# Out:
#              0                 1             2  ...            6    7          8
# 0  Pregnancies  PG Concentration  Diastolic BP  ...  DP Function  Age  Diagnosis
# 1            6               148            72  ...        0.627   50          0
# 2            1                85            66  ...        0.351   31          1
# 3            8               183            64  ...        0.672   32          0
# 4            1                89            66  ...        0.167   21          1
#
# [5 rows x 9 columns]

# %%
df = pd.read_excel('/content/DiabetesDiagnosis.xls')

# %%
df.sample(4)
# Out:
#      Pregnancies  PG Concentration  Diastolic BP  ...  DP Function  Age  Diagnosis
# 489            8               194            80  ...        0.551   67          1
# 535            4               132             0  ...        0.302   23          0
# 589            0                73             0  ...        0.342   25          1
# 718            1               108            60  ...        0.415   24          1
#
# [4 rows x 9 columns]

# %%
df.sample(frac=0.01)
# Out:
#      Pregnancies  PG Concentration  Diastolic BP  ...  DP Function  Age  Diagnosis
# 569            0               121            66  ...        0.203   33          0
# 83             0               101            65  ...        0.237   22          1
# 558           11               103            68  ...        0.126   42          1
# 698            4               127            88  ...        0.598   28          1
# 39             4               111            72  ...        1.390   56          0
# 41             7               133            84  ...        0.696   37          1
# 627            0               132            78  ...        0.393   21          1
# 746            1               147            94  ...        0.358   27          0
#
# [8 rows x 9 columns]

# %%
df['Age']
# Out:
# 0      50
# 1      31
# 2      32
# 3      21
# 4      33
#        ..
# 763    63
# 764    27
# 765    30
# 766    47
# 767    23
# Name: Age, Length: 768, dtype: int64

# %%
df[['Age','BMI','Diagnosis']]
# Out:
#      Age   BMI  Diagnosis
# 0     50  33.6          0
# 1     31  26.6          1
# 2     32  23.3          0
# 3     21  28.1          1
# 4     33  43.1          0
# ..   ...   ...        ...
# 763   63  32.9          1
# 764   27  36.8          1
# 765   30  26.2          1
# 766   47  30.1          0
# 767   23  30.4          1
#
# [768 rows x 3 columns]

# %%
f = ['Age','BMI','Diagnosis']
df[f]
# Out:
#      Age   BMI  Diagnosis
# 0     50  33.6          0
# 1     31  26.6          1
# 2     32  23.3          0
# 3     21  28.1          1
# 4     33  43.1          0
# ..   ...   ...        ...
# 763   63  32.9          1
# 764   27  36.8          1
# 765   30  26.2          1
# 766   47  30.1          0
# 767   23  30.4          1
#
# [768 rows x 3 columns]

# %%
df['Diagnosis'].value_counts()
# Out:
# 1    500
# 0    268
# Name: Diagnosis, dtype: int64

# %%
df.values
# Out:
# array([[  6.   , 148.   ,  72.   , ...,   0.627,  50.   ,   0.   ],
#        [  1.   ,  85.   ,  66.   , ...,   0.351,  31.   ,   1.   ],
#        [  8.   , 183.   ,  64.   , ...,   0.672,  32.   ,   0.   ],
#        ...,
#        [  5.   , 121.   ,  72.   , ...,   0.245,  30.   ,   1.   ],
#        [  1.   , 126.   ,  60.   , ...,   0.349,  47.   ,   0.   ],
#        [  1.   ,  93.   ,  70.   , ...,   0.315,  23.   ,   1.   ]])

# %%
df.iloc[3:7,2:5]
# Out:
#    Diastolic BP  Tri Fold Thick  Serum Ins
# 3            66              23         94
# 4            40              35        168
# 5            74               0          0
# 6            50              32         88

# %%
df.loc[2:5,'Age']
# Out:
# 2    32
# 3    21
# 4    33
# 5    30
# Name: Age, dtype: int64

# %%
df['Age']>35
# Out:
# 0       True
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 763     True
# 764    False
# 765    False
# 766     True
# 767    False
# Name: Age, Length: 768, dtype: bool

# %%
df[df['Age']>35]
# Out:
#      Pregnancies  PG Concentration  Diastolic BP  ...  DP Function  Age  Diagnosis
# 0              6               148            72  ...        0.627   50          0
# 8              2               197            70  ...        0.158   53          0
# 9              8               125            96  ...        0.232   54          0
# 12            10               139            80  ...        1.441   57          1
# 13             1               189            60  ...        0.398   59          0
# ..           ...               ...           ...  ...          ...  ...        ...
# 757            0               123            72  ...        0.258   52          0
# 759            6               190            92  ...        0.278   66          0
# 761            9               170            74  ...        0.403   43          0
# 763           10               101            76  ...        0.171   63          1
# ...

# %%
df[(df['Age']>35) & (df['BMI']<30)]
# Out:
#      Pregnancies  PG Concentration  Diastolic BP  ...  DP Function  Age  Diagnosis
# 9              8               125            96  ...        0.232   54          0
# 12            10               139            80  ...        1.441   57          1
# 14             5               166            72  ...        0.587   51          0
# 28            13               145            82  ...        0.245   57          1
# 34            10               122            78  ...        0.512   45          1
# ..           ...               ...           ...  ...          ...  ...        ...
# 711            5               126            78  ...        0.439   40          1
# 717           10                94            72  ...        0.595   56          1
# 722            1               149            68  ...        0.349   42          0
# 734            2               105            75  ...        0.560   53          1
# ...

# %%
df[df['Age']>35]['Diagnosis']
# Out:
# 0      0
# 8      0
# 9      0
# 12     1
# 13     0
#       ..
# 757    0
# 759    0
# 761    0
# 763    1
# 766    0
# Name: Diagnosis, Length: 270, dtype: int64

# %%
df.loc[df['Age']>35, 'Diagnosis']
# Out:
# 0      0
# 8      0
# 9      0
# 12     1
# 13     0
#       ..
# 757    0
# 759    0
# 761    0
# 763    1
# 766    0
# Name: Diagnosis, Length: 270, dtype: int64

# %%
df['new_col'] = 'ok'
df.head(3)
# Out:
#    Pregnancies  PG Concentration  Diastolic BP  ...  Age  Diagnosis  new_col
# 0            6               148            72  ...   50          0       ok
# 1            1                85            66  ...   31          1       ok
# 2            8               183            64  ...   32          0       ok
#
# [3 rows x 10 columns]

# %%
df['new_col'] = df['BMI'] / df['Age']
df.head(3)
# Out:
#    Pregnancies  PG Concentration  Diastolic BP  ...  Age  Diagnosis   new_col
# 0            6               148            72  ...   50          0  0.672000
# 1            1                85            66  ...   31          1  0.858065
# 2            8               183            64  ...   32          0  0.728125
#
# [3 rows x 10 columns]

# %%
del df['new_col']

# %%
df.drop('new_col', axis=1)

# %%
df.drop([2,4,9], axis=0)

# %%
df.sort_values(by='Age', ascending=True)
# Out:
#      Pregnancies  PG Concentration  Diastolic BP  ...  DP Function  Age  Diagnosis
# 255            1               113            64  ...        0.543   21          0
# 60             2                84             0  ...        0.304   21          1
# 102            0               125            96  ...        0.262   21          1
# 182            1                 0            74  ...        0.299   21          1
# 623            0                94            70  ...        0.347   21          1
# ..           ...               ...           ...  ...          ...  ...        ...
# 123            5               132            80  ...        0.186   69          1
# 684            5               136            82  ...        0.640   69          1
# 666            4               145            82  ...        0.235   70          0
# 453            2               119             0  ...        0.832   72          1
# ...

# %%
df.sort_values(by=['Age','BMI'], ascending=[True,False])
# Out:
#      Pregnancies  PG Concentration  Diastolic BP  ...  DP Function  Age  Diagnosis
# 623            0                94            70  ...        0.347   21          1
# 577            2               118            80  ...        0.693   21          0
# 354            3                90            78  ...        0.559   21          1
# 580            0               151            90  ...        0.371   21          0
# 486            1               139            62  ...        0.536   21          1
# ..           ...               ...           ...  ...          ...  ...        ...
# 123            5               132            80  ...        0.186   69          1
# 684            5               136            82  ...        0.640   69          1
# 666            4               145            82  ...        0.235   70          0
# 453            2               119             0  ...        0.832   72          1
# ...

# %%
df.rename(columns={'Age':'age'})
# Out:
#      Pregnancies  PG Concentration  Diastolic BP  ...  DP Function  age  Diagnosis
# 0              6               148            72  ...        0.627   50          0
# 1              1                85            66  ...        0.351   31          1
# 2              8               183            64  ...        0.672   32          0
# 3              1                89            66  ...        0.167   21          1
# 4              0               137            40  ...        2.288   33          0
# ..           ...               ...           ...  ...          ...  ...        ...
# 763           10               101            76  ...        0.171   63          1
# 764            2               122            70  ...        0.340   27          1
# 765            5               121            72  ...        0.245   30          1
# 766            1               126            60  ...        0.349   47          0
# ...

# %%
df.rename(columns={'Age':'age'})
# Out:
#      Pregnancies  PG Concentration  Diastolic BP  ...  DP Function  age  Diagnosis
# 0              6               148            72  ...        0.627   50          0
# 1              1                85            66  ...        0.351   31          1
# 2              8               183            64  ...        0.672   32          0
# 3              1                89            66  ...        0.167   21          1
# 4              0               137            40  ...        2.288   33          0
# ..           ...               ...           ...  ...          ...  ...        ...
# 763           10               101            76  ...        0.171   63          1
# 764            2               122            70  ...        0.340   27          1
# 765            5               121            72  ...        0.245   30          1
# 766            1               126            60  ...        0.349   47          0
# ...

# %%
df2 = df.copy()

# %%
df_a = df.append(df2)

# %%
df_all = df.append([df1, df2, df3])

# %%
df_j = pd.merge(df, df2, on='', how='inner')

# %%
df1 = pd.DataFrame({'A':[1,2,3,4], 'B':[1,2,3,4], 'C':[2,3,4,5]})
df2 = pd.DataFrame({'A':[3,4,5,6], 'B':[4,5,6,7], 'D':[6,7,8,9]})
print(df1)
print('***********')
print(df2)
# Out:
#    A  B  C
# 0  1  1  2
# 1  2  2  3
# 2  3  3  4
# 3  4  4  5
# ***********
#    A  B  D
# 0  3  4  6
# 1  4  5  7
# 2  5  6  8
# 3  6  7  9

# %%
df_a = df2.append(df1)
df_a
# Out:
#    A  B    D    C
# 0  3  4  6.0  NaN
# 1  4  5  7.0  NaN
# 2  5  6  8.0  NaN
# 3  6  7  9.0  NaN
# 0  1  1  NaN  2.0
# 1  2  2  NaN  3.0
# 2  3  3  NaN  4.0
# 3  4  4  NaN  5.0

# %%
df_j = pd.merge(df1, df2, how='left', on='A')
df_j
# Out:
#    A  B_x  C  B_y    D
# 0  1    1  2  NaN  NaN
# 1  2    2  3  NaN  NaN
# 2  3    3  4  4.0  6.0
# 3  4    4  5  5.0  7.0

# %%
df_j = pd.merge(df1, df2, how='left', on=['A','B'])
df_j
# Out:
#    A  B  C   D
# 0  1  1  2 NaN
# 1  2  2  3 NaN
# 2  3  3  4 NaN
# 3  4  4  5 NaN

# %%
df_new = pd.concat([df1, df2], axis=1)
df_new
# Out:
#    A  B  C  A  B  D
# 0  1  1  2  3  4  6
# 1  2  2  3  4  5  7
# 2  3  3  4  5  6  8
# 3  4  4  5  6  7  9

# %%
import numpy as np
df = df.rename(columns={'age':'Age'})

# %%
a = df.groupby('Diagnosis').agg( {'Age':np.mean, 'BMI':np.max} )
a
# Out:
#                  Age   BMI
# Diagnosis
# 0          37.067164  67.1
# 1          31.190000  57.3

# %%
a = df.groupby(['Pregnancies','Diagnosis']).agg( {'Age':np.mean, 'BMI':np.max} )
a
# Out:
#                              Age   BMI
# Pregnancies Diagnosis
# 0           0          28.578947  67.1
#             1          27.095890  52.3
# 1           0          35.103448  55.0
#             1          25.254717  46.3
# 2           0          32.947368  45.5
#             1          25.892857  42.7
# 3           0          29.481481  38.4
#             1          28.770833  57.3
# 4           0          38.086957  48.3
#             1          30.066667  44.5
# 5           0          38.380952  52.9
#             1          39.416667  45.0
# 6           0          44.000000  46.2
#             1          37.147059  46.1
# 7           0          40.000000  50.0
#             1          42.500000  46.7
# 8           0          42.272727  47.9
#             1          49.625000  38.7
# 9           0          43.166667  45.4
#             1          46.000000  35.4
# 10          0          41.700000  45.6
#             1          43.357143  35.9
# ...

# %%
df_ = df.drop('Age', axis=1)
df_.head(2)
# Out:
#    Pregnancies  PG Concentration  Diastolic BP  ...   BMI  DP Function  Diagnosis
# 0            6               148            72  ...  33.6        0.627          0
# 1            1                85            66  ...  26.6        0.351          1
#
# [2 rows x 8 columns]

# %%
df_ = df.drop([2,3,5], axis=0)
df_.head(4)
# Out:
#    Pregnancies  PG Concentration  Diastolic BP  ...  DP Function  Age  Diagnosis
# 0            6               148            72  ...        0.627   50          0
# 1            1                85            66  ...        0.351   31          1
# 4            0               137            40  ...        2.288   33          0
# 6            3                78            50  ...        0.248   26          0
#
# [4 rows x 9 columns]

# %%
cor = df.corr()
cor
# Out:
#                   Pregnancies  PG Concentration  ...       Age  Diagnosis
# Pregnancies          1.000000          0.129459  ...  0.544341  -0.221898
# PG Concentration     0.129459          1.000000  ...  0.263514  -0.466581
# Diastolic BP         0.141282          0.152590  ...  0.239528  -0.065068
# Tri Fold Thick      -0.081672          0.057328  ... -0.113970  -0.074752
# Serum Ins           -0.073535          0.331357  ... -0.042163  -0.130548
# BMI                  0.017683          0.221071  ...  0.036242  -0.292695
# DP Function         -0.033523          0.137337  ...  0.033561  -0.173844
# Age                  0.544341          0.263514  ...  1.000000  -0.238356
# Diagnosis           -0.221898         -0.466581  ... -0.238356   1.000000
#
# [9 rows x 9 columns]

# %%
from seaborn import heatmap
heatmap(cor)

# %%
df = pd.read_excel('/content/Heart data.xlsx')

# %%
df.isna()
# Out:
#        age    sex  chest pain  blood pressure  ...  slope     ca   thal      c
# 0    False  False       False           False  ...  False  False  False  False
# 1    False  False       False           False  ...  False  False  False  False
# 2    False  False       False           False  ...  False  False  False  False
# 3    False  False       False           False  ...  False  False  False  False
# 4    False  False       False           False  ...  False  False  False  False
# ..     ...    ...         ...             ...  ...    ...    ...    ...    ...
# 592  False  False       False           False  ...  False   True   True  False
# 593  False  False       False           False  ...  False   True   True  False
# 594  False  False       False           False  ...  False   True   True  False
# 595  False  False       False           False  ...   True   True   True  False
# 596  False  False       False           False  ...  False   True   True  False
#
# [597 rows x 14 columns]

# %%
df.isna().sum()
# Out:
# age                       0
# sex                       0
# chest pain                0
# blood pressure            1
# cholestoral              23
# blood sugar               8
# electrocardiographic      1
# heart rate                1
# exercise induced          1
# depression                0
# slope                   190
# ca                      290
# thal                    266
# c                         0
# dtype: int64

# %%
df[df['blood sugar'].isna()]
# Out:
#      age  sex  chest pain  blood pressure  ...  slope   ca  thal  c
# 183   53    0           2           113.0  ...    NaN  NaN   NaN  0
# 213   46    1           3           150.0  ...    NaN  NaN   NaN  0
# 289   49    1           4           120.0  ...    2.0  NaN   NaN  0
# 301   56    0           3           130.0  ...    NaN  NaN     7  0
# 314   38    0           2           120.0  ...    NaN  NaN   NaN  0
# 316   54    0           2           140.0  ...    NaN  NaN   NaN  0
# 421   40    1           4           120.0  ...    2.0  NaN     6  1
# 431   41    1           4           120.0  ...    2.0  NaN   NaN  1
#
# [8 rows x 14 columns]

# %%
import numpy as np

# %%
df[df=='?'] = np.nan

# %%
df_new=df.dropna(axis=0)
print(df.shape, df_new.shape)
# Out:
# (597, 14) (298, 14)

# %%
df_new=df.dropna(axis=0,thresh=11)
print(df.shape, df_new.shape)
# Out:
# (597, 14) (575, 14)

# %%
df_new=df.dropna(axis=1,thresh=590)
print(df.shape, df_new.shape)
# Out:
# (597, 14) (597, 9)

# %%
df.fillna(0)

# %%
df[['cholestoral','blood sugar']].fillna(0)
# Out:
#      cholestoral  blood sugar
# 0          233.0          1.0
# 1          250.0          0.0
# 2          204.0          0.0
# 3          236.0          0.0
# 4          354.0          0.0
# ..           ...          ...
# 592        266.0          0.0
# 593        288.0          0.0
# 594        336.0          0.0
# 595        491.0          0.0
# 596        222.0          0.0
#
# [597 rows x 2 columns]

# %%
df.fillna(df.mean())
# Out:
#      age  sex  chest pain  blood pressure  ...     slope        ca     thal  c
# 0     63    1           1           145.0  ...  3.000000  0.000000  6.00000  0
# 1     37    1           3           130.0  ...  3.000000  0.000000  3.00000  0
# 2     41    0           2           130.0  ...  1.000000  0.000000  3.00000  0
# 3     56    1           2           120.0  ...  1.000000  0.000000  3.00000  0
# 4     57    0           4           120.0  ...  1.000000  0.000000  3.00000  0
# ..   ...  ...         ...             ...  ...       ...       ...      ... ..
# 592   52    1           4           140.0  ...  2.000000  0.693069  4.81155  1
# 593   43    1           4           140.0  ...  2.000000  0.693069  4.81155  1
# 594   41    1           4           120.0  ...  2.000000  0.693069  4.81155  1
# 595   44    1           4           135.0  ...  1.675676  0.693069  4.81155  1
# 596   49    1           4           150.0  ...  2.000000  0.693069  4.81155  1
#
# [597 rows x 14 columns]

# %%
(df['cholestoral'].ffill() + df['cholestoral'].bfill()) / 2
# Out:
# 0      233.0
# 1      250.0
# 2      204.0
# 3      236.0
# 4      354.0
#        ...
# 592    266.0
# 593    288.0
# 594    336.0
# 595    491.0
# 596    222.0
# Name: cholestoral, Length: 597, dtype: float64

# %%
df_d = df.drop_duplicates(subset=['Age','BMI'], keep='last')
print(df.shape, df_d.shape)
# Out:
# (768, 9) (708, 9)

# %%
df = pd.read_excel('/content/Farm.xlsx')
df.head(3)
# Out:
#       id     name    region  ...  maincrop          claimtype  claimvalue
# 0  id601  name601  midlands  ...     wheat  decommission_land     74703.1
# 1  id602  name602     north  ...     maize         arable_dev    245354.0
# 2  id603  name603  midlands  ...  rapeseed  decommission_land     84213.0
#
# [3 rows x 10 columns]

# %%
df.dtypes
# Out:
# id              object
# name            object
# region          object
# farmsize         int64
# rainfall         int64
# landquality      int64
# farmincome     float64
# maincrop        object
# claimtype       object
# claimvalue     float64
# dtype: object

# %%
from sklearn.preprocessing import LabelEncoder
LE = LabelEncoder()
df['region'] = LE.fit_transform(df['region'])
df.head(3)
# Out:
#       id     name  region  ...  maincrop          claimtype  claimvalue
# 0  id601  name601       0  ...     wheat  decommission_land     74703.1
# 1  id602  name602       1  ...     maize         arable_dev    245354.0
# 2  id603  name603       0  ...  rapeseed  decommission_land     84213.0
#
# [3 rows x 10 columns]

# %%
LE.inverse_transform([0,1,2,3])
# Out:
# array(['midlands', 'north', 'southeast', 'southwest'], dtype=object)

# %%
df_d = pd.get_dummies(df, columns=['region','maincrop','claimtype'])
df_d.head(3)
# Out:
#       id     name  ...  claimtype_arable_dev  claimtype_decommission_land
# 0  id601  name601  ...                     0                            1
# 1  id602  name602  ...                     1                            0
# 2  id603  name603  ...                     0                            1
#
# [3 rows x 17 columns]

# %%
df_d = pd.get_dummies(df, columns=['region','maincrop','claimtype'], dummy_na=True)
df_d.head(3)
# Out:
#       id     name  ...  claimtype_decommission_land  claimtype_nan
# 0  id601  name601  ...                            1              0
# 1  id602  name602  ...                            0              0
# 2  id603  name603  ...                            1              0
#
# [3 rows x 20 columns]

# %%
df_d = pd.get_dummies(df, columns=['region','maincrop','claimtype'], drop_first=True)
df_d.head(3)
# Out:
#       id     name  ...  maincrop_wheat  claimtype_decommission_land
# 0  id601  name601  ...               1                            1
# 1  id602  name602  ...               0                            0
# 2  id603  name603  ...               0                            1
#
# [3 rows x 14 columns]

# %%
from sklearn.preprocessing import MinMaxScaler, StandardScaler
MMS = MinMaxScaler()
df_norm = MMS.fit_transform(df)
df_norm
# Out:
# array([[0.35294118, 0.74371859, 0.59016393, ..., 0.23441503, 0.48333333,
#         0.        ],
#        [0.05882353, 0.42713568, 0.54098361, ..., 0.11656704, 0.16666667,
#         1.        ],
#        [0.47058824, 0.91959799, 0.52459016, ..., 0.25362938, 0.18333333,
#         0.        ],
#        ...,
#        [0.29411765, 0.6080402 , 0.59016393, ..., 0.07130658, 0.15      ,
#         1.        ],
#        [0.05882353, 0.63316583, 0.49180328, ..., 0.11571307, 0.43333333,
#         0.        ],
#        [0.05882353, 0.46733668, 0.57377049, ..., 0.10119556, 0.03333333,
#         1.        ]])

# %%
from sklearn.preprocessing import StandardScaler
SS = StandardScaler()
df_norm = SS.fit_transform(df)
df_norm
# Out:
# array([[ 0.63994726,  0.84832379,  0.14964075, ...,  0.46849198,
#          1.4259954 , -1.36589591],
#        [-0.84488505, -1.12339636, -0.16054575, ..., -0.36506078,
#         -0.19067191,  0.73212021],
#        [ 1.23388019,  1.94372388, -0.26394125, ...,  0.60439732,
#         -0.10558415, -1.36589591],
#        ...,
#        [ 0.3429808 ,  0.00330087,  0.14964075, ..., -0.68519336,
#         -0.27575966,  0.73212021],
#        [-0.84488505,  0.1597866 , -0.47073225, ..., -0.37110101,
#          1.17073215, -1.36589591],
#        [-0.84488505, -0.8730192 ,  0.04624525, ..., -0.47378505,
#         -0.87137393,  0.73212021]])

# %%
df_norm = pd.DataFrame(df_norm, columns=df.columns)
