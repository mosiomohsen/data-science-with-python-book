# %%
pip install --upgrade category_encoders
# Out:
# Requirement already up-to-date: category_encoders in /usr/local/lib/python3.7/dist-packages (2.2.2)
# Requirement already satisfied, skipping upgrade: scipy>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from category_encoders) (1.4.1)
# Requirement already satisfied, skipping upgrade: numpy>=1.14.0 in /usr/local/lib/python3.7/dist-packages (from category_encoders) (1.19.5)
# Requirement already satisfied, skipping upgrade: scikit-learn>=0.20.0 in /usr/local/lib/python3.7/dist-packages (from category_encoders) (0.22.2.post1)
# Requirement already satisfied, skipping upgrade: statsmodels>=0.9.0 in /usr/local/lib/python3.7/dist-packages (from category_encoders) (0.10.2)
# Requirement already satisfied, skipping upgrade: patsy>=0.5.1 in /usr/local/lib/python3.7/dist-packages (from category_encoders) (0.5.1)
# Requirement already satisfied, skipping upgrade: pandas>=0.21.1 in /usr/local/lib/python3.7/dist-packages (from category_encoders) (1.1.5)
# Requirement already satisfied, skipping upgrade: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.20.0->category_encoders) (1.0.1)
# Requirement already satisfied, skipping upgrade: six in /usr/local/lib/python3.7/dist-packages (from patsy>=0.5.1->category_encoders) (1.15.0)
# Requirement already satisfied, skipping upgrade: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.21.1->category_encoders) (2.8.1)
# Requirement already satisfied, skipping upgrade: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.21.1->category_encoders) (2018.9)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split, KFold
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import accuracy_score, confusion_matrix, f1_score
import xgboost
import lightgbm
import category_encoders as ce

from warnings import filterwarnings
filterwarnings('ignore')
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
df = pd.read_csv('/content/train_insurance.csv', nrows=1000)
df.head()
# Out:
#    perc_premium_paid_by_cash_credit  age_in_days  ...  premium  renewal
# 0                             0.429        12058  ...     3300        1
# 1                             0.917        17531  ...     3300        0
# 2                             0.049        15341  ...     9600        1
# 3                             0.052        31400  ...     9600        1
# 4                             1.000        24829  ...     7500        1
#
# [5 rows x 12 columns]

# %%
X = df.drop('renewal', axis=1)
y = df['renewal']
y.value_counts()
# Out:
# 1    930
# 0     70
# Name: renewal, dtype: int64

# %%
# X = X.fillna(-1)
X.isnull().sum()
# Out:
# perc_premium_paid_by_cash_credit     0
# age_in_days                          0
# Income                               0
# Count_3.6_months_late                1
# Count_6.12_months_late               1
# Count_more_than_12_months_late       1
# application_underwriting_score      36
# no_of_premiums_paid                  0
# sourcing_channel                     0
# residence_area_type                  0
# premium                              0
# dtype: int64

# %%
import category_encoders as ce

cat_features = ['sourcing_channel',	'residence_area_type']
encoder = ce.TargetEncoder(cols=cat_features)
encoder.fit(X[cat_features], y)
X = X.join(encoder.transform(X[cat_features]).add_suffix('_tb'))
X.head()

# %%
cat_features = ['sourcing_channel',	'residence_area_type']
encoder = ce.CatBoostEncoder(cols=cat_features)
encoder.fit(X[cat_features], y)
X = X.join(encoder.transform(X[cat_features]).add_suffix('_cb'))
X.head()
# Out:
#    perc_premium_paid_by_cash_credit  ...  residence_area_type_cb
# 0                             0.429  ...                0.929624
# 1                             0.917  ...                0.930590
# 2                             0.049  ...                0.929624
# 3                             0.052  ...                0.929624
# 4                             1.000  ...                0.929624
#
# [5 rows x 13 columns]

# %%
X = X.drop(cat_features, axis=1)

# %%
Xnew = X.copy()
cols = X.columns
i = 0
for c1 in cols:
  j = 0
  for c2 in cols:
    if i<j:
      Xnew[c1+'/'+c2] = (Xnew[c1]+0.0001) / (Xnew[c2]+0.0001)
    j += 1
  i+= 1
Xnew.head()
# Out:
#    perc_premium_paid_by_cash_credit  ...  sourcing_channel_cb/residence_area_type_cb
# 0                             0.429  ...                                    0.987977
# 1                             0.917  ...                                    0.986952
# 2                             0.049  ...                                    1.013347
# 3                             0.052  ...                                    1.006907
# 4                             1.000  ...                                    1.006907
#
# [5 rows x 66 columns]

# %%
X = X.fillna(0)
Xnew = Xnew.fillna(0)

# %%
Xtrain, Xtest, Ytrain, Ytest = train_test_split(Xnew, y, test_size=0.2)

# %%
Xnew.shape
# Out:
# (1000, 66)

# %%
# Feature ranking with recursive feature elimination.
from sklearn.svm import SVC
from sklearn.feature_selection import RFE
estimator = SVC(kernel="linear")
selector = RFE(estimator, n_features_to_select=10, step=5)
selector = selector.fit(Xnew, y)
selector.support_
# selector.ranking_

# %%
# The feature ranking, such that ranking_[i] corresponds to the ranking position of the i-th feature.
# Selected features are assigned rank 1.

# %%
lgb = lightgbm.LGBMClassifier(random_state=2020, n_estimators=2000, num_leaves=15, learning_rate=0.011, colsample_bytree=0.85,
                              verbose=1, class_weight='balanced', importance='gain')
lgb.fit(Xtrain, Ytrain, eval_set=(Xtest, Ytest), verbose=100, early_stopping_rounds=50, eval_metric='auc')
pred = lgb.predict(Xtest, num_iteration=lgb.best_iteration_)
print(f1_score(Ytest, pred, pos_label=0))
# Out:
# Training until validation scores don't improve for 50 rounds.
# [100]	valid_0's binary_logloss: 0.396665
# [200]	valid_0's binary_logloss: 0.287272
# [300]	valid_0's binary_logloss: 0.247696
# [400]	valid_0's binary_logloss: 0.231667
# [500]	valid_0's binary_logloss: 0.222323
# Early stopping, best iteration is:
# [530]	valid_0's binary_logloss: 0.221786
# 0.3448275862068966

# %%
imp = pd.DataFrame({'Importance':lgb.feature_importances_,'Feature':Xnew.columns})
plt.figure(figsize=(8, 6))
sns.set(font_scale = 1)
sns.barplot(x="Importance", y="Feature", data=imp.sort_values(by="Importance", ascending=False)[:20])
plt.title('LightGBM Features')
plt.tight_layout()
plt.show()
imp.sort_values(by="Importance", ascending=False)
# Out:
#     Importance                                            Feature
# 56         314  application_underwriting_score/no_of_premiums_...
# 35         298                                     Income/premium
# 23         295                 age_in_days/Count_6.12_months_late
# 15         247  perc_premium_paid_by_cash_credit/Count_more_th...
# 28         241                    age_in_days/sourcing_channel_cb
# ..         ...                                                ...
# 55           0  Count_more_than_12_months_late/residence_area_...
# 5            0                     Count_more_than_12_months_late
# 4            0                             Count_6.12_months_late
# 45           0  Count_6.12_months_late/Count_more_than_12_mont...
# 3            0                              Count_3.6_months_late
#
# [66 rows x 2 columns]

# %%
imp = imp.sort_values(by="Importance", ascending=False)
best_feats = list(imp['Feature'].values[:7])
best_feats
# Out:
# ['application_underwriting_score/no_of_premiums_paid',
#  'Income/premium',
#  'age_in_days/Count_6.12_months_late',
#  'perc_premium_paid_by_cash_credit/Count_more_than_12_months_late',
#  'age_in_days/sourcing_channel_cb',
#  'no_of_premiums_paid/premium',
#  'age_in_days/no_of_premiums_paid']

# %%
lgb = lightgbm.LGBMClassifier(random_state=2020, n_estimators=200000, num_leaves=15, learning_rate=0.011, colsample_bytree=0.9,
                              verbose=1, class_weight='balanced')
lgb.fit(Xtrain[best_feats], Ytrain, eval_set=(Xtest[best_feats], Ytest), verbose=500, early_stopping_rounds=50)
pred = lgb.predict(Xtest[best_feats], num_iteration=lgb.best_iteration_)
print(f1_score(Ytest, pred, pos_label=0))
# Out:
# Training until validation scores don't improve for 50 rounds.
# [500]	valid_0's binary_logloss: 0.23327
# Early stopping, best iteration is:
# [540]	valid_0's binary_logloss: 0.231914
# 0.4444444444444445

# %%
# Permutation Importance
def premutation_importance(Xtrain, Xtest, Ytrain, Ytest):
  lgb = lightgbm.LGBMClassifier(random_state=2020, n_estimators=500, num_leaves=15, learning_rate=0.011, colsample_bytree=0.85,
                              verbose=0, class_weight='balanced')
  lgb.fit(Xtrain, Ytrain, eval_set=(Xtest, Ytest), verbose=0, early_stopping_rounds=20)
  pred = lgb.predict(Xtest, num_iteration=lgb.best_iteration_)
  baseline = f1_score(Ytest, pred, pos_label=0)
  perm = {}
  features = Xtrain.columns
  for f in features:
      value = Xtrain[f].copy()
      Xtrain[f] = np.random.permutation(Xtrain[f].values)
      lgb = lightgbm.LGBMClassifier(random_state=2020, n_estimators=500, num_leaves=15, learning_rate=0.011, colsample_bytree=0.85,
                              verbose=0, class_weight='balanced')
      lgb.fit(Xtrain, Ytrain, eval_set=(Xtest, Ytest), verbose=0, early_stopping_rounds=20)
      pred = lgb.predict(Xtest, num_iteration=lgb.best_iteration_)
      f1 = f1_score(Ytest, pred, pos_label=0)
      Xtrain[f] = np.random.permutation(Xtrain[f].values)
      lgb = lightgbm.LGBMClassifier(random_state=2020, n_estimators=500, num_leaves=15, learning_rate=0.011, colsample_bytree=0.85,
                              verbose=0, class_weight='balanced')
      lgb.fit(Xtrain, Ytrain, eval_set=(Xtest, Ytest), verbose=0, early_stopping_rounds=20)
      pred = lgb.predict(Xtest, num_iteration=lgb.best_iteration_)
      f2 = f1_score(Ytest, pred, pos_label=0)

      perm[f] = baseline - (f1+f2)/2
      Xtrain[f] = value.copy()

  perm_df = pd.DataFrame({'feature':list(perm.keys()), 'weight':list(perm.values())})
  perm_df = perm_df[perm_df.weight>=0]
  best_features = list(perm_df['feature'].values)
  return best_features

# %%
Xtrain, Xtest, Ytrain, Ytest = train_test_split(Xnew, y, test_size=0.2)
best_features = premutation_importance(Xtrain, Xtest, Ytrain, Ytest)
# Out:
# perc_premium_paid_by_cash_credit 0.058064516129032295
# age_in_days 0.14050179211469543
# Income 0.09032258064516135
# Count_3.6_months_late 0.07919911012235825
# Count_6.12_months_late 0.0
# Count_more_than_12_months_late 0.0
# application_underwriting_score 0.03225806451612906
# no_of_premiums_paid 0.13634196726521536
# premium 0.11368186874304786
# sourcing_channel_cb 0.10678531701890992
# residence_area_type_cb 0.05339265850945496
# perc_premium_paid_by_cash_credit/age_in_days 0.189247311827957
# perc_premium_paid_by_cash_credit/Income 0.08494623655913985
# perc_premium_paid_by_cash_credit/Count_3.6_months_late 0.1458657767890249
# perc_premium_paid_by_cash_credit/Count_6.12_months_late 0.12572004608294934
# perc_premium_paid_by_cash_credit/Count_more_than_12_months_late 0.09139784946236562
# perc_premium_paid_by_cash_credit/application_underwriting_score 0.18875576036866365
# perc_premium_paid_by_cash_credit/no_of_premiums_paid 0.06979472140762466
# perc_premium_paid_by_cash_credit/premium 0.14208909370199696
# perc_premium_paid_by_cash_credit/sourcing_channel_cb 0.039491691104594384
# perc_premium_paid_by_cash_credit/residence_area_type_cb 0.06411290322580654
# age_in_days/Income 0.12903225806451613
# age_in_days/Count_3.6_months_late 0.07919911012235825
# age_in_days/Count_6.12_months_late 0.12618186874304793
# age_in_days/Count_more_than_12_months_late 0.16553372059489974
# age_in_days/application_underwriting_score 0.15092165898617516
# age_in_days/no_of_premiums_paid 0.11520737327188946
# age_in_days/premium 0.11253244345569158
# age_in_days/sourcing_channel_cb 0.1412680756395996
# age_in_days/residence_area_type_cb 0.07919911012235825
# Income/Count_3.6_months_late 0.10875576036866363
# Income/Count_6.12_months_late 0.0
# Income/Count_more_than_12_months_late 0.1412680756395996
# Income/application_underwriting_score 0.11469534050179214
# Income/no_of_premiums_paid 0.07919911012235825
# Income/premium 0.0
# Income/sourcing_channel_cb 0.1982972533584325
# Income/residence_area_type_cb 0.08787541713014463
# Count_3.6_months_late/Count_6.12_months_late 0.02580645161290329
# Count_3.6_months_late/Count_more_than_12_months_late 0.11827956989247318
# Count_3.6_months_late/application_underwriting_score 0.08494623655913985
# Count_3.6_months_late/no_of_premiums_paid 0.11368186874304786
# Count_3.6_months_late/premium 0.1301843317972351
# Count_3.6_months_late/sourcing_channel_cb 0.03225806451612906
# Count_3.6_months_late/residence_area_type_cb 0.10678531701890992
# Count_6.12_months_late/Count_more_than_12_months_late 0.05339265850945496
# Count_6.12_months_late/application_underwriting_score 0.11253244345569158
# Count_6.12_months_late/no_of_premiums_paid 0.11679147465437789
# Count_6.12_months_late/premium 0.08565072302558402
# Count_6.12_months_late/sourcing_channel_cb 0.12903225806451618
# Count_6.12_months_late/residence_area_type_cb 0.10678531701890992
# Count_more_than_12_months_late/application_underwriting_score 0.1034647550776584
# Count_more_than_12_months_late/no_of_premiums_paid 0.08494623655913985
# Count_more_than_12_months_late/premium 0.009188660801564108
# Count_more_than_12_months_late/sourcing_channel_cb 0.10678531701890992
# Count_more_than_12_months_late/residence_area_type_cb 0.05339265850945496
# application_underwriting_score/no_of_premiums_paid 0.08565072302558402
# application_underwriting_score/premium 0.11568409343715241
# application_underwriting_score/sourcing_channel_cb 0.08494623655913985
# application_underwriting_score/residence_area_type_cb 0.07919911012235825
# no_of_premiums_paid/premium 0.09656820335352045
# no_of_premiums_paid/sourcing_channel_cb 0.07919911012235825
# no_of_premiums_paid/residence_area_type_cb 0.02580645161290329
# premium/sourcing_channel_cb 0.10875576036866363
# premium/residence_area_type_cb 0.05161290322580653
# sourcing_channel_cb/residence_area_type_cb 0.10875576036866363

# %%
best_features
# Out:
# ['Income/sourcing_channel_cb',
#  'perc_premium_paid_by_cash_credit/age_in_days',
#  'perc_premium_paid_by_cash_credit/application_underwriting_score',
#  'age_in_days/Count_more_than_12_months_late',
#  'age_in_days/application_underwriting_score',
#  'perc_premium_paid_by_cash_credit/Count_3.6_months_late',
#  'perc_premium_paid_by_cash_credit/premium',
#  'Income/Count_more_than_12_months_late',
#  'age_in_days/sourcing_channel_cb',
#  'age_in_days',
#  'no_of_premiums_paid',
#  'Count_3.6_months_late/premium',
#  'Count_6.12_months_late/sourcing_channel_cb',
#  'age_in_days/Income',
#  'age_in_days/Count_6.12_months_late',
#  'perc_premium_paid_by_cash_credit/Count_6.12_months_late',
#  'Count_3.6_months_late/Count_more_than_12_months_late',
#  'Count_6.12_months_late/no_of_premiums_paid',
#  'application_underwriting_score/premium',
#  'age_in_days/no_of_premiums_paid']

# %%
lgb = lightgbm.LGBMClassifier(random_state=2020, n_estimators=20000, num_leaves=15, learning_rate=0.011, colsample_bytree=0.9,
                              verbose=1, class_weight='balanced')
lgb.fit(Xtrain[best_feats], Ytrain, eval_set=(Xtest[best_feats], Ytest), verbose=500, early_stopping_rounds=50)
pred = lgb.predict(Xtest[best_feats], num_iteration=lgb.best_iteration_)
print(f1_score(Ytest, pred, pos_label=0))
# Out:
# Training until validation scores don't improve for 50 rounds.
# Early stopping, best iteration is:
# [260]	valid_0's binary_logloss: 0.334003
# 0.3243243243243243

# %%
# !pip install eli5
# Out:
# Collecting eli5
#   Downloading https://files.pythonhosted.org/packages/d1/54/04cab6e1c0ae535bec93f795d8403fdf6caf66fa5a6512263202dbb14ea6/eli5-0.11.0-py2.py3-none-any.whl (106kB)
#      |████████████████████████████████| 112kB 7.4MB/s
# Requirement already satisfied: tabulate>=0.7.7 in /usr/local/lib/python3.7/dist-packages (from eli5) (0.8.9)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.7/dist-packages (from eli5) (2.11.3)
# Requirement already satisfied: scikit-learn>=0.20 in /usr/local/lib/python3.7/dist-packages (from eli5) (0.22.2.post1)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from eli5) (1.15.0)
# Requirement already satisfied: numpy>=1.9.0 in /usr/local/lib/python3.7/dist-packages (from eli5) (1.19.5)
# Requirement already satisfied: attrs>16.0.0 in /usr/local/lib/python3.7/dist-packages (from eli5) (21.2.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from eli5) (1.4.1)
# Requirement already satisfied: graphviz in /usr/local/lib/python3.7/dist-packages (from eli5) (0.10.1)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from jinja2->eli5) (2.0.1)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.20->eli5) (1.0.1)
# Installing collected packages: eli5
# Successfully installed eli5-0.11.0

# %%
import eli5
from eli5.sklearn import PermutationImportance

# %%
lgb = lightgbm.LGBMClassifier(random_state=2020, n_estimators=20000, num_leaves=15, learning_rate=0.011, colsample_bytree=0.9,
                              verbose=1, class_weight='balanced')
lgb.fit(Xtrain, Ytrain, eval_set=(Xtest, Ytest), verbose=500, early_stopping_rounds=50)
pred = lgb.predict(Xtest, num_iteration=lgb.best_iteration_)
print(f1_score(Ytest, pred, pos_label=0))
# Out:
# Training until validation scores don't improve for 50 rounds.
# [500]	valid_0's binary_logloss: 0.218689
# Early stopping, best iteration is:
# [525]	valid_0's binary_logloss: 0.218298
# 0.3448275862068966

# %%
from eli5 import show_weights
show_weights(lgb)
# Out:
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <table class="eli5-weights eli5-feature-importances" style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto;">
#     <thead>
#     <tr style="border: none;">
#         <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;">Weight</th>
#         <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#     </tr>
#     </thead>
#     <tbody>
#
#         <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.1495
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Count_6.12_months_late/no_of_premiums_paid
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 86.76%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0829
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 perc_premium_paid_by_cash_credit/sourcing_channel_cb
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 89.76%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0574
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Income/Count_3.6_months_late
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 90.05%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0552
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 age_in_days/Count_6.12_months_late
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 91.32%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0454
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 perc_premium_paid_by_cash_credit/Count_more_than_12_months_late
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 92.35%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0379
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Income/premium
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 93.19%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0321
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 age_in_days/sourcing_channel_cb
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 93.47%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0302
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 perc_premium_paid_by_cash_credit/age_in_days
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 93.92%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0273
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 perc_premium_paid_by_cash_credit/application_underwriting_score
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 94.38%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0244
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 application_underwriting_score/no_of_premiums_paid
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 94.44%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0240
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 application_underwriting_score
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 94.58%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0232
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 perc_premium_paid_by_cash_credit/residence_area_type_cb
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 94.83%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0216
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 age_in_days/Count_more_than_12_months_late
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 94.99%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0207
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 age_in_days/Income
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 95.01%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0206
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 no_of_premiums_paid/premium
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 95.04%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0204
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Count_more_than_12_months_late/application_underwriting_score
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 95.16%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0197
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Count_more_than_12_months_late/sourcing_channel_cb
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 95.39%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0184
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 perc_premium_paid_by_cash_credit/Count_3.6_months_late
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 95.40%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0183

# %%
import eli5
from eli5.sklearn import PermutationImportance
perm = PermutationImportance(lgb, random_state=2020).fit(Xtest, Ytest)

# %%
eli5.show_weights(perm, feature_names = Xtest.columns.tolist(), top=66)
# Out:
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <table class="eli5-weights eli5-feature-importances" style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto;">
#     <thead>
#     <tr style="border: none;">
#         <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;">Weight</th>
#         <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#     </tr>
#     </thead>
#     <tbody>
#
#         <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0190
#
#                     &plusmn; 0.0117
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 age_in_days/application_underwriting_score
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 88.15%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0090
#
#                     &plusmn; 0.0040
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Count_more_than_12_months_late/application_underwriting_score
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 88.15%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0090
#
#                     &plusmn; 0.0133
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Count_6.12_months_late/sourcing_channel_cb
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 89.08%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0080
#
#                     &plusmn; 0.0102
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Income/premium
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 90.06%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0070
#
#                     &plusmn; 0.0080
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Count_6.12_months_late/application_underwriting_score
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 92.14%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0050
#
#                     &plusmn; 0.0089
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 application_underwriting_score
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 92.14%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0050
#
#                     &plusmn; 0.0000
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Income/Count_3.6_months_late
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 92.14%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0050
#
#                     &plusmn; 0.0063
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Count_6.12_months_late/no_of_premiums_paid
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 92.14%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0050
#
#                     &plusmn; 0.0063
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 perc_premium_paid_by_cash_credit/sourcing_channel_cb
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 92.14%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0050
#
#                     &plusmn; 0.0000
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Count_more_than_12_months_late/residence_area_type_cb
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 93.28%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0040
#
#                     &plusmn; 0.0040
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Count_3.6_months_late/residence_area_type_cb
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 93.28%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0040
#
#                     &plusmn; 0.0040
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 application_underwriting_score/residence_area_type_cb
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 93.28%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0040
#
#                     &plusmn; 0.0040
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 application_underwriting_score/sourcing_channel_cb
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 94.51%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0030
#
#                     &plusmn; 0.0049
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Count_more_than_12_months_late/sourcing_channel_cb
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 94.51%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0030
#
#                     &plusmn; 0.0102
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 age_in_days/Count_6.12_months_late
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 94.51%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0030
#
#                     &plusmn; 0.0049
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 age_in_days/Income
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 94.51%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
